# %%
from main import *
from matplotlib import cm
from numpy import cos, sin

# %% [markdown]
# No. 23
# x = t,
# y = 1/(1 + t^2),
# z = t^2

# %%
draw_graph(lambda t: (t, 1 / (1 + t**2), t**2), auto_scale=False)

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(0, 5 * np.pi, 1000)
x = t * np.cos(t)
y = t * np.sin(t)
z = t

plt.plot(x,y,z,label="f1")

u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:80j]
x = np.cos(u)*np.sin(v) * y.max()
y = np.sin(u)*np.sin(v) * y.max()
z = np.sqrt(x**2 + y**2)
ax.plot_surface(x,y,z, cmap = cm.viridis, alpha=0.5, label='f2')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# ax.view_init(azim=15, elev=15)
ax.set_aspect('equal')
plt.show()

# %%
draw_graph(lambda t:(cos(t)*sin(2*t), sin(t) * sin(2*t), cos(2*t)))

# %%
draw_graph(lambda t:(t**2, np.log(t), t), t_start=np.nextafter(0,1))

# %%
draw_graph(lambda t:(t, t * sin(t), t * cos(t)))

# %%
draw_graph(lambda t:(t, np.exp(t), cos(t)))

# %%
draw_graph(lambda t:(cos(2*t), cos(3*t), cos(4*t)))

# %%
draw_graph(lambda t:(sin(t), sin(2*t), cos(4*t)))

# %%
fig  = plt.figure()
ax = fig.add_subplot()
t = np.linspace(-2 * np.pi, 2 * np.pi, 1000)
x,y,z = sin(t), sin(2*t), cos(4*t)
ax.plot(x,y, color='r', alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.show()

fig  = plt.figure()
ax = fig.add_subplot()
ax.plot(x,z, color='r', alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Z')

fig  = plt.figure()
ax = fig.add_subplot()
ax.plot(y,z, color='r', alpha=0.5)
ax.set_xlabel('Y')
ax.set_ylabel('Z')
# Out:
# Text(0, 0.5, 'Z')

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(-5 * np.pi, 5 * np.pi, 1000)
x = (1+cos(16*t))*cos(t)
y = (1+cos(16*t))*sin(t)
z = 1 + cos(16 * t)

plt.plot(x,y,z,label="f1")

u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:80j]
x = np.cos(u)*np.sin(v) * x.max()
y = np.sin(u)*np.sin(v) * x.max()
z = np.sqrt(x**2 + y**2)
ax.plot_surface(x,y,z, cmap = cm.viridis, alpha=0.5, label='f2')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# ax.view_init(azim=15, elev=15)
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(-5 * np.pi, 5 * np.pi, 1000)
x = np.sqrt(1 - 0.25*cos(10*t)**2) * cos(t)
y = np.sqrt(1 - 0.25*cos(10*t)**2) * sin(t)
z = 0.5 * cos(10*t)

plt.plot(x,y,z,label="f1")

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = x.max() * np.outer(np.cos(u), np.sin(v))
y = x.max() * np.outer(np.sin(u), np.sin(v))
z = x.max() * np.outer(np.ones(np.size(u)), np.cos(v))
ax.plot_surface(x,y,z, cmap = cm.viridis, alpha=0.5, label='f2')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# ax.view_init(azim=15, elev=15)
ax.set_aspect('equal')
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')

u = np.linspace(0, 2 * np.pi, 1000)
v = np.linspace(0, np.pi, 1000)

size = 1
x = size * np.outer(np.cos(u), np.sin(v))
y = size * np.outer(np.sin(u), np.sin(v))
z = np.sqrt(x**2 + y**2)
ax.plot_surface(x,y,z, color='r', alpha=0.5, label='f2')

x = np.linspace(-size, size, 1000)
y = np.linspace(-size, size, 1000)
x, y = np.meshgrid(x, y)
z = 1 + y

ax.plot_surface(x,y,z, color='b', alpha=0.5, label='f1')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(azim=-45, elev=20)
ax.set_aspect('equal')
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')

u = np.linspace(0, 2 * np.pi, 1000)
v = np.linspace(0, np.pi, 1000)
z = np.linspace(-2, 4, 1000)

size = 2
x = 2 * cos(u)
y = 2 * sin(u)
_,z = np.meshgrid(u, z)
ax.plot_surface(x,y,z, color='r', alpha=0.5) 

x = np.linspace(-size, size, 1000)
y = np.linspace(-size, size, 1000)
x, y = np.meshgrid(x, y)
z = x**2

ax.plot_surface(x,y,z, color='b', alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_zlim(-2, 4)
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
# ax.view_init(azim=-45, elev=30)
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# x = 2 * cos(t),
# y = 2 * sin(t)
# z = 4 * cos(t) ** 2

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

x = 2*cos(t)
y = 2*sin(t)
z = 4*cos(t)**2

ax.plot(x,y,z, color='r', alpha=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_zlim(-2, 4)
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
# ax.view_init(azim=160, elev=30)
ax.set_aspect('equal')
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')

x = np.linspace(-2, 2, 1000)
z = np.linspace(-2, 2, 1000)
x, z = np.meshgrid(x, z)

y = x*x
ax.plot_surface(x,y,z, color='r', alpha=0.5)

x = np.linspace(-2, 2, 1000)
y = np.linspace(-2, 2, 1000)
x, y = np.meshgrid(x, y)
z = np.sqrt(16 - x**2 - 4 * y**2) / 2

ax.plot_surface(x,y,z, color='b', alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(azim=160, elev=30)
ax.set_zlim(-2, 4)
ax.set_xlim(-2, 4)
ax.set_ylim(-2, 4)
# ax.set_aspect('equal')
plt.show()
# Out:
# D:\Other\User\Temp\ipykernel_25060\2872437659.py:14: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(16 - x**2 - 4 * y**2) / 2

# %% [markdown]
# x = t
# y = t**2
# z = sqrt(16 - t**2 - 4 * t**4) / 2

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

x = t
y = t**2
z = np.sqrt(4 - 1/4*t**2 - t**4)

ax.plot(x,y,z, color='r', alpha=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_zlim(-2, 4)
ax.set_xlim(-2, 4)
ax.set_ylim(-2, 4)
ax.view_init(azim=160, elev=30)
ax.set_aspect('equal')
plt.show()
# Out:
# D:\Other\User\Temp\ipykernel_25060\857594197.py:7: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(4 - 1/4*t**2 - t**4)

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
t = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

x = (2 + cos(1.5 * t)) * cos(t)
y = (2 + cos(1.5 * t)) * sin(t)
z = sin(1.5 * t)

ax.plot(x,y,z, color='r', alpha=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_zlim(-4, 1)
ax.set_xlim(-4, 2)
ax.set_ylim(-4, 2)
ax.view_init(azim=160, elev=30)
ax.set_aspect('equal')
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot()
t = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

x = (2 + cos(1.5 * t)) * cos(t)
y = (2 + cos(1.5 * t)) * sin(t)
z = sin(1.5 * t)

ax.plot(x,y, color='r', alpha=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_aspect('equal')
plt.show()

fig  = plt.figure()
ax = fig.add_subplot()

ax.plot(x,z, color='r', alpha=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Z')
ax.set_aspect('equal')
plt.show()

fig  = plt.figure()
ax = fig.add_subplot()

ax.plot(y,z, color='r', alpha=0.5)

ax.set_xlabel('Y')
ax.set_ylabel('Z')
ax.set_aspect('equal')
plt.show()
